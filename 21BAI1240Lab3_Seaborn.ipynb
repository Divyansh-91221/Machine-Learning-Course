# %% [markdown]
# # BCSE209P - Machine Learning Lab

# %% [markdown]
# ## Lab 3 - Seaborn

# %% [markdown]
# ### By -Divyansh (21BAI1240)

# %%
import seaborn as sb

# %%
from google.colab import drive
drive.mount('/root/gdrive', force_remount=True)

from google.colab import auth
auth.authenticate_user()
from googleapiclient.discovery import build
drive_service = build('drive', 'v3')
drive_service.files().emptyTrash().execute()
# Out:
# Mounted at /root/gdrive
# ''

# %%
print(sb.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df1=sb.load_dataset("glue")
df1.info()
df1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Model    64 non-null     object
#  1   Year     64 non-null     int64
#  2   Encoder  64 non-null     object
#  3   Task     64 non-null     object
#  4   Score    64 non-null     float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 2.6+ KB
#          Model  Year      Encoder  Task  Score
# 0        ERNIE  2019  Transformer  CoLA   75.5
# 1           T5  2019  Transformer  CoLA   71.6
# 2      RoBERTa  2019  Transformer  CoLA   67.8
# 3         BERT  2018  Transformer  CoLA   60.5
# 4  BiLSTM+ELMo  2018         LSTM  CoLA   32.1

# %%
import matplotlib.pyplot as plt
plt.scatter(df1['Year'],df1['Score'])
plt.show()

# %%
sb.relplot(x="Year", y="Score", data=df1, kind='line', hue="Task")

# %%
sb.relplot(x="Year",y="Score",data=df1,kind='line',col="Task")

# %%
import numpy as np
df2=np.random.randint(6,size=(3,6))
print(df2)
sb.heatmap(df2,annot=True)
# Out:
# [[3 3 2 0 3 0]
#  [4 5 3 0 3 0]
#  [2 3 3 1 4 5]]
# <Axes: >

# %%
df1=sb.load_dataset("geyser")
df1.info()
df1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 272 entries, 0 to 271
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   duration  272 non-null    float64
#  1   waiting   272 non-null    int64
#  2   kind      272 non-null    object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.5+ KB
#    duration  waiting   kind
# 0     3.600       79   long
# 1     1.800       54  short
# 2     3.333       74   long
# 3     2.283       62  short
# 4     4.533       85   long

# %%
sb.catplot(x="kind",y="waiting",kind="box",data=df1)

# %%
sb.pairplot(df1)

# %%
df3=df1.corr()
print(df3)
sb.heatmap(df3,annot=True)
# Out:
#           duration   waiting
# duration  1.000000  0.900811
# waiting   0.900811  1.000000
# <ipython-input-12-11aaebbce8b9>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df3=df1.corr()
# <Axes: >
